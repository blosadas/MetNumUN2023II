# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
#
# Mi CC termina en 1
#
# - **(x+1)(x-10)(x-3)(x+2)(x-4)(x+9)(x-4)(x-2)(x-3)(x-1)**
# = x^10 - 15 x^9 - 8 x^8 + 1094 x^7 - 6239 x^6 + 9821 x^5 + 18318 x^4 - 70804 x^3 + 39768 x^2 + 59904 x - 51840
#
# - **(x^10 - 15 x^9 - 8 x^8 + 1094 x^7 - 6239 x^6 + 9821 x^5 + 18318 x^4 - 70804 x^3 + 39768 x^2 + 59904 x - 51840)/(x - 10)** = x^10/(x - 10) - (15 x^9)/(x - 10) - (8 x^8)/(x - 10) + (1094 x^7)/(x - 10) - (6239 x^6)/(x - 10) + (9821 x^5)/(x - 10) + (18318 x^4)/(x - 10) - (70804 x^3)/(x - 10) + (39768 x^2)/(x - 10) + (59904 x)/(x - 10) - 51840/(x - 10)

# %% [markdown]
# ![grade 10.png](data:image/png;base64,...)

# %% [markdown]
# Dividiendo por una raiz del polinomio:
#
# **(x^10 - 15 x^9 - 8 x^8 + 1094 x^7 - 6239 x^6 + 9821 x^5 + 18318 x^4 - 70804 x^3 + 39768 x^2 + 59904 x - 51840)/(x - 10)**

# %% [markdown]
# ![grade 9.png](data:image/png;base64,...)

# %% [markdown]
# Dividiendo por una raiz que no es del polinomio:
#
# **(x^10 - 15 x^9 - 8 x^8 + 1094 x^7 - 6239 x^6 + 9821 x^5 + 18318 x^4 - 70804 x^3 + 39768 x^2 + 59904 x - 51840)/(x - 69)**

# %% [markdown]
# ![grade 8.png](data:image/png;base64,...)

# %% [markdown]
# Polinomio en Sympy:

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 15*x**9 - 8*x**8 + 1094*x**7 - 6239*x**6 + 9821*x**5 + 18318*x**4 - 70804*x**3 + 39768*x**2 + 59904*x - 51840

roots = [(-1), 10, 3, (-2), 4, (-9), 4, 2, 3, 1]

for i in roots:
  p, r = div(p, x-i)
  print(f"Raiz: (x-{i}): ")
  print(f"Cociente: {p}")
  print(f"Residuo: {r}\n")
# Out:
# Raiz: (x--1):
# Cociente: x**9 - 16*x**8 + 8*x**7 + 1086*x**6 - 7325*x**5 + 17146*x**4 + 1172*x**3 - 71976*x**2 + 111744*x - 51840
# Residuo: 0
#
# Raiz: (x-10):
# Cociente: x**8 - 6*x**7 - 52*x**6 + 566*x**5 - 1665*x**4 + 496*x**3 + 6132*x**2 - 10656*x + 5184
# Residuo: 0
#
# Raiz: (x-3):
# Cociente: x**7 - 3*x**6 - 61*x**5 + 383*x**4 - 516*x**3 - 1052*x**2 + 2976*x - 1728
# Residuo: 0
#
# Raiz: (x--2):
# Cociente: x**6 - 5*x**5 - 51*x**4 + 485*x**3 - 1486*x**2 + 1920*x - 864
# Residuo: 0
#
# Raiz: (x-4):
# Cociente: x**5 - x**4 - 55*x**3 + 265*x**2 - 426*x + 216
# Residuo: 0
#
# Raiz: (x--9):
# Cociente: x**4 - 10*x**3 + 35*x**2 - 50*x + 24
# Residuo: 0
#
# Raiz: (x-4):
# Cociente: x**3 - 6*x**2 + 11*x - 6
# Residuo: 0
#
# Raiz: (x-2):
# Cociente: x**2 - 4*x + 3
# Residuo: 0
#
# Raiz: (x-3):
# Cociente: x - 1
# Residuo: 0
#
# Raiz: (x-1):
# Cociente: 1
# Residuo: 0

# %% [markdown]
# Polinomio en sympy dividido por una raiz que no está

# %%
p = x**10 - 15*x**9 - 8*x**8 + 1094*x**7 - 6239*x**6 + 9821*x**5 + 18318*x**4 - 70804*x**3 + 39768*x**2 + 59904*x - 51840

p, r = div(p,  x-69)

print(p)
print(r)
# Out:
# x**9 + 54*x**8 + 3718*x**7 + 257636*x**6 + 17770645*x**5 + 1226184326*x**4 + 84606736812*x**3 + 5837864769224*x**2 + 402812669116224*x + 27794074169079360
# 1917791117666424000

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*5 - 15\*x\*\*4  + 85\*x\*\*3 - 225\*x\*\*2 + 274\*x - 120)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram3.jpg" />

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**5 - 15*x**4  + 85*x**3 - 225*x**2 + 274*x - 120)
# Out:
# (x - 5)*(x - 4)*(x - 3)*(x - 2)*(x - 1)

# %% [markdown]
# factorizando mi polinomio:

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 15*x**9 - 8*x**8 + 1094*x**7 - 6239*x**6 + 9821*x**5 + 18318*x**4 - 70804*x**3 + 39768*x**2 + 59904*x - 51840)
# Out:
# (x - 10)*(x - 4)**2*(x - 3)**2*(x - 2)*(x - 1)*(x + 1)*(x + 2)*(x + 9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x\*\*5 - 15\*x\*\*4  + 85\*x\*\* 3 - 225\*x\*\* 2 + 274\*x - 120 = 0

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram4.jpg" />

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**5 - 15*x**4  + 85*x**3 - 225*x**2 + 274*x - 120, 0), x)
# Out:
# FiniteSet(1, 2, 3, 4, 5)

# %% [markdown]
# Sympy solver a mi polinomio

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 15*x**9 - 8*x**8 + 1094*x**7 - 6239*x**6 + 9821*x**5 + 18318*x**4 - 70804*x**3 + 39768*x**2 + 59904*x - 51840, 0), x)
# Out:
# {-9, -2, -1, 1, 2, 3, 4, 10}

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram5.jpg" />

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2 - (sqrt(2)+E)*x + (sqrt(2)*pi) , 0), x)
# Out:
# FiniteSet(sqrt(2)/2 + E/2 - I*sqrt(-(sqrt(2) + E)**2 + 4*sqrt(2)*pi)/2, sqrt(2)/2 + E/2 + I*sqrt(-(sqrt(2) + E)**2 + 4*sqrt(2)*pi)/2)

# %% [markdown]
# Polinomio con numeros irracionales

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq( x**9 - x**6 + (sqrt(9)+pi)*x**7 - 3*x**12 + (sqrt(34)+pi)*x**5 - 11**x*4, 0), x)
# Out:
# ConditionSet(x, Eq(-4*11**x - 3*x**12 + x**9 + x**7*(3 + pi) - x**6 + x**5*(pi + sqrt(34)), 0), Complexes)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram6.jpg" />

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**5 - 2*x**4  - x**3 + 8*x**2 - 10*x - 4,domain='GF(3)')
# Out:
# (x + 1)*(x**4 - x**2 - 1)

# %% [markdown]
# Factorizando con Modulo 2

# %%
from sympy import Symbol,factor
y = Symbol('x')
factor(x**10 - 15*x**9 - 8*x**8 + 1094*x**7 - 6239*x**6 + 9821*x**5 + 18318*x**4 - 70804*x**3 + 39768*x**2 + 59904*x - 51840, domain='GF(2)')
# Out:
# x**5*(x + 1)**5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram8.jpg" />

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram9.jpg" />

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**3, x)
# Out:
# -x**2*sin(x)**2*cos(x) - 2*x**2*cos(x)**3/3 + 14*x*sin(x)**3/9 + 4*x*sin(x)*cos(x)**2/3 + 14*sin(x)**2*cos(x)/9 + 40*cos(x)**3/27

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram10.jpg" />

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**3, (x,1,5))
# Out:
# 70*sin(5)**3/9 - 211*sin(5)**2*cos(5)/9 - 14*sin(1)**3/9 + 20*sin(5)*cos(5)**2/3 - 410*cos(5)**3/27 - 4*sin(1)*cos(1)**2/3 - 5*sin(1)**2*cos(1)/9 - 22*cos(1)**3/27

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**2 * sin(x)**3, (x,1,5)))
# Out:
# -15.4297821533056
